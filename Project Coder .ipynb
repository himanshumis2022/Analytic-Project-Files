# %% [markdown]
# # Loading and Cleaning Dataset

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('survey_results_public.csv') #loading the CSV file in notebook

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.isnull().sum() #checking the total number of total NULL values in dataset
# Out:
# Respondent                0
# MainBranch              299
# Hobbyist                 45
# Age                   19015
# Age1stCode             6561
#                       ...
# WebframeWorkedWith    22182
# WelcomeChange         11778
# WorkWeekHrs           23310
# YearsCode              6777
# YearsCodePro          18112
# Length: 61, dtype: int64

# %%
df.shape #for checking rows and columns in dataset
# Out:
# (64461, 61)

# %%
df.sample(10)
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 7409         7439                     I am a developer by profession      Yes
# 27183       27284                     I am a developer by profession       No
# 55141       56253                     I am a developer by profession      Yes
# 54584       55694                        I code primarily as a hobby      Yes
# 34702       34829                     I am a developer by profession      Yes
# 37686       38040                     I am a developer by profession      Yes
# 38620       39066                     I am a developer by profession      Yes
# 22685       22773                     I am a developer by profession      Yes
# 23316       23405  I am not primarily a developer, but I write co...       No
# 53656       54750  I am not primarily a developer, but I write co...      Yes
#
#         Age Age1stCode CompFreq   CompTotal  ConvertedComp     Country  \
# ...

# %%
df1='survey_results_schema.csv'

# %%
df2=pd.read_csv(df1, index_col='Column').QuestionText #loading another dataset of question

# %%
df2
# Out:
# Column
# Respondent            Randomized respondent ID number (not in order ...
# MainBranch            Which of the following options best describes ...
# Hobbyist                                        Do you code as a hobby?
# Age                   What is your age (in years)? If you prefer not...
# Age1stCode            At what age did you write your first line of c...
#                                             ...
# WebframeWorkedWith    Which web frameworks have you done extensive d...
# WelcomeChange         Compared to last year, how welcome do you feel...
# WorkWeekHrs           On average, how many hours per week do you wor...
# YearsCode             Including any education, how many years have y...
# YearsCodePro          NOT including education, how many years have y...
# Name: QuestionText, Length: 61, dtype: object

# %%
type(df1)
# Out:
# str

# %%
df2.Age
# Out:
# 'What is your age (in years)? If you prefer not to answer, you may leave this question blank.'

# %%
s_columns=['Hobbyist', 'Age', 'Age1stCode', 'Country','UndergradMajor',
       'DevType', 'EdLevel', 'Gender', 'WorkWeekHrs', 'LanguageDesireNextYear', 'Employment','LanguageWorkedWith','JobFactors',
       'JobSat', 'NEWEdImpt','NEWOvertime','NEWStuck','NEWLearn','YearsCode','YearsCodePro']

# %%
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'Age', 'Age1stCode', 'CompFreq',
#        'CompTotal', 'ConvertedComp', 'Country', 'CurrencyDesc',
#        'CurrencySymbol', 'DatabaseDesireNextYear', 'DatabaseWorkedWith',
#        'DevType', 'EdLevel', 'Employment', 'Ethnicity', 'Gender', 'JobFactors',
#        'JobSat', 'JobSeek', 'LanguageDesireNextYear', 'LanguageWorkedWith',
#        'MiscTechDesireNextYear', 'MiscTechWorkedWith',
#        'NEWCollabToolsDesireNextYear', 'NEWCollabToolsWorkedWith', 'NEWDevOps',
#        'NEWDevOpsImpt', 'NEWEdImpt', 'NEWJobHunt', 'NEWJobHuntResearch',
#        'NEWLearn', 'NEWOffTopic', 'NEWOnboardGood', 'NEWOtherComms',
#        'NEWOvertime', 'NEWPurchaseResearch', 'NEWPurpleLink', 'NEWSOSites',
#        'NEWStuck', 'OpSys', 'OrgSize', 'PlatformDesireNextYear',
#        'PlatformWorkedWith', 'PurchaseWhat', 'Sexuality', 'SOAccount',
#        'SOComm', 'SOPartFreq', 'SOVisitFreq', 'SurveyEase', 'SurveyLength',
# ...

# %%
df['Country']
# Out:
# 0                   Germany
# 1            United Kingdom
# 2        Russian Federation
# 3                   Albania
# 4             United States
#                 ...
# 64456         United States
# 64457               Morocco
# 64458              Viet Nam
# 64459                Poland
# 64460                 Spain
# Name: Country, Length: 64461, dtype: object

# %%
s_columns
# Out:
# ['Hobbyist',
#  'Age',
#  'Age1stCode',
#  'Country',
#  'UndergradMajor',
#  'DevType',
#  'EdLevel',
#  'Gender',
#  'WorkWeekHrs',
#  'LanguageDesireNextYear',
#  'Employment',
#  'LanguageWorkedWith',
#  'JobFactors',
#  'JobSat',
#  'NEWEdImpt',
#  'NEWOvertime',
#  'NEWStuck',
#  'NEWLearn',
#  'YearsCode',
#  'YearsCodePro']

# %%
survey_df=df[s_columns].copy()

# %%
len(survey_df)
# Out:
# 64461

# %%
survey_df['Index']=np.arange(64461)

# %%
survey_df.head(15)
# Out:
#    Hobbyist   Age Age1stCode             Country  \
# 0       Yes   NaN         13             Germany
# 1        No   NaN         19      United Kingdom
# 2       Yes   NaN         15  Russian Federation
# 3       Yes  25.0         18             Albania
# 4       Yes  31.0         16       United States
# 5        No   NaN         14             Germany
# 6       Yes   NaN         18               India
# 7       Yes  36.0         12       United States
# 8        No  30.0         20             Tunisia
# 9       Yes  22.0         14      United Kingdom
# 10      Yes  23.0         13      United Kingdom
# 11       No  49.0         42               Spain
# 12      Yes  53.0         14         Netherlands
# 13      Yes  27.0         13       United States
# 14      Yes   NaN         13              France
#
#                                        UndergradMajor  \
# 0   Computer science, computer engineering, or sof...
# 1   Computer science, computer engineering, or sof...
# ...

# %%
w=survey_df.groupby(['Hobbyist','Gender'],as_index=False)["Index"].count()
w
# Out:
#    Hobbyist                                             Gender  Index
# 0        No                                                Man   9242
# 1        No  Man;Non-binary, genderqueer, or gender non-con...     19
# 2        No  Non-binary, genderqueer, or gender non-conforming     67
# 3        No                                              Woman   1489
# 4        No                                          Woman;Man     15
# 5        No  Woman;Man;Non-binary, genderqueer, or gender n...      2
# 6        No  Woman;Non-binary, genderqueer, or gender non-c...     23
# 7       Yes                                                Man  36771
# 8       Yes  Man;Non-binary, genderqueer, or gender non-con...    102
# 9       Yes  Non-binary, genderqueer, or gender non-conforming    318
# 10      Yes                                              Woman   2355
# 11      Yes                                          Woman;Man     61
# ...

# %%
df2
# Out:
# Column
# Respondent            Randomized respondent ID number (not in order ...
# MainBranch            Which of the following options best describes ...
# Hobbyist                                        Do you code as a hobby?
# Age                   What is your age (in years)? If you prefer not...
# Age1stCode            At what age did you write your first line of c...
#                                             ...
# WebframeWorkedWith    Which web frameworks have you done extensive d...
# WelcomeChange         Compared to last year, how welcome do you feel...
# WorkWeekHrs           On average, how many hours per week do you wor...
# YearsCode             Including any education, how many years have y...
# YearsCodePro          NOT including education, how many years have y...
# Name: QuestionText, Length: 61, dtype: object

# %%
schema=df2[s_columns]

# %%
schema
# Out:
# Column
# Hobbyist                                            Do you code as a hobby?
# Age                       What is your age (in years)? If you prefer not...
# Age1stCode                At what age did you write your first line of c...
# Country                                                  Where do you live?
# UndergradMajor                        What was your primary field of study?
# DevType                   Which of the following describe you? Please se...
# EdLevel                   Which of the following best describes the high...
# Gender                    Which of the following describe you, if any? P...
# WorkWeekHrs               On average, how many hours per week do you wor...
# LanguageDesireNextYear    Which programming, scripting, and markup langu...
# Employment                Which of the following best describes your cur...
# LanguageWorkedWith        Which programming, scripting, and markup langu...
# ...

# %%
survey_df.shape
# Out:
# (64461, 21)

# %%
survey_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Hobbyist                64416 non-null  object
#  1   Age                     45446 non-null  float64
#  2   Age1stCode              57900 non-null  object
#  3   Country                 64072 non-null  object
#  4   UndergradMajor          50995 non-null  object
#  5   DevType                 49370 non-null  object
#  6   EdLevel                 57431 non-null  object
#  7   Gender                  50557 non-null  object
#  8   WorkWeekHrs             41151 non-null  float64
#  9   LanguageDesireNextYear  54113 non-null  object
#  10  Employment              63854 non-null  object
#  11  LanguageWorkedWith      57378 non-null  object
#  12  JobFactors              49349 non-null  object
#  13  JobSat                  45194 non-null  object
# ...

# %%
survey_df.Age1stCode.unique()
# Out:
# array(['13', '19', '15', '18', '16', '14', '12', '20', '42', '8', '25',
#        '22', '30', '17', '21', '10', '46', '9', '7', '11', '6', nan, '31',
#        '29', '5', 'Younger than 5 years', '28', '38', '23', '27', '41',
#        '24', '53', '26', '35', '32', '40', '33', '36', '54', '48', '56',
#        '45', '44', '34', 'Older than 85', '39', '51', '68', '50', '37',
#        '47', '43', '52', '85', '64', '55', '58', '49', '76', '72', '73',
#        '83', '63'], dtype=object)

# %%
survey_df['Age1stCode']=pd.to_numeric(survey_df.Age1stCode, errors='coerce')
survey_df['YearsCode']=pd.to_numeric(survey_df.YearsCode, errors='coerce')
survey_df['YearsCodePro']=pd.to_numeric(survey_df.YearsCodePro, errors='coerce')

# %%
survey_df.Age1stCode.unique()
# Out:
# array([13., 19., 15., 18., 16., 14., 12., 20., 42.,  8., 25., 22., 30.,
#        17., 21., 10., 46.,  9.,  7., 11.,  6., nan, 31., 29.,  5., 28.,
#        38., 23., 27., 41., 24., 53., 26., 35., 32., 40., 33., 36., 54.,
#        48., 56., 45., 44., 34., 39., 51., 68., 50., 37., 47., 43., 52.,
#        85., 64., 55., 58., 49., 76., 72., 73., 83., 63.])

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode   WorkWeekHrs     YearsCode  YearsCodePro  \
# count  45446.000000  57473.000000  41151.000000  56784.000000  44133.000000
# mean      30.834111     15.476572     40.782174     12.782051      8.869667
# std        9.585392      5.114081     17.816383      9.490657      7.759961
# min        1.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000     40.000000      6.000000      3.000000
# 50%       29.000000     15.000000     40.000000     10.000000      6.000000
# 75%       35.000000     18.000000     44.000000     17.000000     12.000000
# max      279.000000     85.000000    475.000000     50.000000     50.000000
#
#               Index
# count  64461.000000
# mean   32230.000000
# std    18608.432188
# min        0.000000
# 25%    16115.000000
# 50%    32230.000000
# 75%    48345.000000
# max    64460.000000

# %%
survey_df.drop(survey_df[survey_df.Age<10].index, inplace=True)

# %%
survey_df.drop(survey_df[survey_df.Age>100].index, inplace=True)

# %%
survey_df.drop(survey_df[survey_df.WorkWeekHrs>140].index, inplace=True)

# %%
survey_df[survey_df.Age<10].index # it gives the indexes of those values which are less than 10
# Out:
# Index([], dtype='int64')

# %%
survey_df.describe()
# Out:
#                 Age    Age1stCode   WorkWeekHrs     YearsCode  YearsCodePro  \
# count  45319.000000  57326.000000  41002.000000  56636.000000  43993.000000
# mean      30.832322     15.475317     40.024395     12.783883      8.873003
# std        9.505965      5.114952     10.630010      9.494519      7.762089
# min       10.000000      5.000000      1.000000      1.000000      1.000000
# 25%       24.000000     12.000000     40.000000      6.000000      3.000000
# 50%       29.000000     15.000000     40.000000     10.000000      6.000000
# 75%       35.000000     18.000000     43.000000     17.000000     12.000000
# max       99.000000     85.000000    140.000000     50.000000     50.000000
#
#               Index
# count  64306.000000
# mean   32229.498632
# std    18611.449829
# min        0.000000
# 25%    16116.250000
# 50%    32229.500000
# 75%    48351.750000
# max    64460.000000

# %%
survey_df['Gender'].value_counts()   # count values of unique values
# Out:
# Gender
# Man                                                            45895
# Woman                                                           3835
# Non-binary, genderqueer, or gender non-conforming                385
# Man;Non-binary, genderqueer, or gender non-conforming            121
# Woman;Non-binary, genderqueer, or gender non-conforming           92
# Woman;Man                                                         73
# Woman;Man;Non-binary, genderqueer, or gender non-conforming       25
# Name: count, dtype: int64

# %%
survey_df.where(~(survey_df.Gender.str.contains(';',na=False)),np.nan,inplace=True)

# %%
survey_df['Gender'].value_counts()   # count values of unique values
# Out:
# Gender
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: count, dtype: int64

# %%
survey_df.sample(10)
# Out:
#       Hobbyist   Age  Age1stCode              Country  \
# 26947      Yes  29.0        16.0               Serbia
# 33081      Yes  26.0        14.0  Trinidad and Tobago
# 44868      Yes   NaN        12.0                Italy
# 12289      Yes  29.0        13.0              Croatia
# 62075       No   NaN        14.0             Cameroon
# 64038      Yes   NaN         NaN        United States
# 13000      Yes  23.0        16.0       United Kingdom
# 44660       No   NaN         8.0               France
# 9096       Yes  37.0        14.0          Netherlands
# 12417       No  35.0         5.0              Morocco
#
#                                           UndergradMajor  \
# 26947  Information systems, information technology, o...
# 33081  Computer science, computer engineering, or sof...
# 44868                                                NaN
# 12289  Information systems, information technology, o...
# 62075  Computer science, computer engineering, or sof...
# ...

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size']=14
matplotlib.rcParams['figure.figsize']=(9,5)
matplotlib.rcParams['figure.facecolor']='#00000000'

# %%
survey_df.Country.nunique()
# Out:
# 183

# %%
survey_df.Country.value_counts()
# Out:
# Country
# United States          12371
# India                   8364
# United Kingdom          3881
# Germany                 3864
# Canada                  2175
#                        ...
# Nauru                      1
# Lesotho                    1
# Saint Lucia                1
# Antigua and Barbuda        1
# Marshall Islands           1
# Name: count, Length: 183, dtype: int64

# %%
top_countries=survey_df.Country.value_counts().head(15)

# %%
top_countries
# Out:
# Country
# United States         12371
# India                  8364
# United Kingdom         3881
# Germany                3864
# Canada                 2175
# France                 1884
# Brazil                 1804
# Netherlands            1332
# Poland                 1259
# Australia              1199
# Spain                  1157
# Italy                  1115
# Russian Federation     1085
# Sweden                  879
# Pakistan                802
# Name: count, dtype: int64

# %%
top_countries.index
# Out:
# Index(['United States', 'India', 'United Kingdom', 'Germany', 'Canada',
#        'France', 'Brazil', 'Netherlands', 'Poland', 'Australia', 'Spain',
#        'Italy', 'Russian Federation', 'Sweden', 'Pakistan'],
#       dtype='object', name='Country')

# %% [markdown]
# # Visulization

# %%
plt.figure(figsize=(10,6))
plt.xticks(rotation=70)
plt.title(schema.Country)
sns.barplot(x=top_countries.index, y=top_countries, alpha=1);

# %%
plt.figure(figsize=(10,6))
plt.title('Distibution of Age')
plt.xlabel('Age')
plt.ylabel('Number of Respondent')
plt.hist(survey_df.Age, bins=np.arange(10,80,5), color='purple');

# %%
man=survey_df[survey_df['Gender']=='Man']
man1=man.Age
woman=survey_df[survey_df['Gender']=='Woman']
woman1=woman.Age

# %%
plt.figure(figsize=(10,6))
plt.title('Distibution of Age of Male')
plt.xlabel('Age')
plt.ylabel('Number of Respondent')
plt.hist(man.Age, bins=np.arange(10,80,5), color='blue');

# %%
gender_counts=survey_df.Gender.value_counts()
gender_counts
# Out:
# Gender
# Man                                                  45895
# Woman                                                 3835
# Non-binary, genderqueer, or gender non-conforming      385
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,5))
plt.title(schema.Gender)
plt.pie(gender_counts,labels=gender_counts.index,autopct='%.1f%%');

# %%
man2=man.count()

# %%
plt.figure(figsize=(10,5))
plt.title('Man')
plt.pie(man2,labels=man.columns,autopct='%.1f%%');

# %%
schema.EdLevel
# Out:
# 'Which of the following best describes the highest level of formal education that you’ve completed?'

# %%
survey_df.EdLevel.unique()
# Out:
# array(['Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#        'Bachelor’s degree (B.A., B.S., B.Eng., etc.)', nan,
#        'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#        'Professional degree (JD, MD, etc.)',
#        'Some college/university study without earning a degree',
#        'Associate degree (A.A., A.S., etc.)',
#        'Other doctoral degree (Ph.D., Ed.D., etc.)',
#        'Primary/elementary school',
#        'I never completed any formal education'], dtype=object)

# %%
sns.countplot(y=survey_df.EdLevel)
plt.xticks(rotation=75);
plt.title(schema.EdLevel,fontsize=26)
plt.ylabel(None);

# %%
undergrad_pct=survey_df.UndergradMajor.value_counts()*100/survey_df.UndergradMajor.count()
sns.barplot(x=undergrad_pct,y=undergrad_pct.index);

plt.title(schema.UndergradMajor,fontsize=26)
plt.xlabel('Percentage')
plt.ylabel(None);

# %%
(survey_df.Employment.value_counts(normalize=True,ascending=True)*100).plot.barh();
plt.title(schema.Employment,fontsize=26);

# %% [markdown]
# # Machine Learning

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %%
df1=survey_df.head(1000)

# %%
df1.isnull().sum()
# Out:
# Hobbyist                    2
# Age                       125
# Age1stCode                 18
# Country                     2
# UndergradMajor            120
# DevType                   150
# EdLevel                    31
# Gender                     55
# WorkWeekHrs               230
# LanguageDesireNextYear     72
# Employment                  9
# LanguageWorkedWith         16
# JobFactors                101
# JobSat                    191
# NEWEdImpt                 148
# NEWOvertime               198
# NEWStuck                   23
# NEWLearn                   51
# YearsCode                  22
# YearsCodePro              202
# Index                       2
# dtype: int64

# %%
df1=df1.dropna()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 546 entries, 7 to 999
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Hobbyist                546 non-null    object
#  1   Age                     546 non-null    float64
#  2   Age1stCode              546 non-null    float64
#  3   Country                 546 non-null    object
#  4   UndergradMajor          546 non-null    object
#  5   DevType                 546 non-null    object
#  6   EdLevel                 546 non-null    object
#  7   Gender                  546 non-null    object
#  8   WorkWeekHrs             546 non-null    float64
#  9   LanguageDesireNextYear  546 non-null    object
#  10  Employment              546 non-null    object
#  11  LanguageWorkedWith      546 non-null    object
#  12  JobFactors              546 non-null    object
#  13  JobSat                  546 non-null    object
# ...

# %%
df1.describe()
# Out:
#               Age  Age1stCode  WorkWeekHrs   YearsCode  YearsCodePro  \
# count  546.000000  546.000000   546.000000  546.000000    546.000000
# mean    32.854396   14.862637    39.930403   15.481685      9.331502
# std      8.278709    5.131071     7.362234    9.672843      7.621914
# min     19.000000    5.000000     4.000000    1.000000      1.000000
# 25%     27.000000   12.000000    39.625000    8.000000      3.000000
# 50%     32.000000   14.000000    40.000000   13.000000      7.000000
# 75%     37.000000   17.000000    40.000000   21.000000     13.000000
# max     63.000000   42.000000    80.000000   45.000000     40.000000
#
#             Index
# count  546.000000
# mean   504.826007
# std    286.740462
# min      7.000000
# 25%    256.500000
# 50%    502.500000
# 75%    757.750000
# max    999.000000

# %%
plt.scatter(df1.YearsCode,df1.YearsCodePro,marker='o',color='red');
plt.xlabel('Years of Coding');
plt.ylabel('Years of Coding as Professional');

# %%
X_train, X_test, y_train, y_test = train_test_split(df1[['Age','YearsCode']],df1.YearsCodePro,train_size=0.8,random_state  =42)

# %%
X_test
# Out:
#       Age  YearsCode
# 575  53.0       38.0
# 156  40.0       22.0
# 654  30.0       12.0
# 179  24.0        9.0
# 909  37.0       15.0
# ..    ...        ...
# 646  32.0       10.0
# 86   22.0        5.0
# 115  30.0       19.0
# 290  28.0        8.0
# 99   55.0       30.0
#
# [110 rows x 2 columns]

# %%
model.score(X_train,y_train)
# Out:
# 0.859434863128496

# %%
model=make_pipeline(StandardScaler(), LinearRegression())

# %%
model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('linearregression', LinearRegression())])

# %%
age=int(input("Enter the Age of the person :"))
ycode=int(input("Enter the Number of years he learns to code :"))

print("So the person should worked ",model.predict([[age,ycode]])," as Profession")

#by this we can predict that if the persons age is 50 years and he is doing coding by 25 years 
#then for how many year he works as a professional in coding, 
#which gives as idea that how fastly peoples are learnig the code and becoming professional
# Out:
# Enter the Age of the person :23
# Enter the Number of years he learns to code :4
# So the person should worked  [0.46696383]  as Profession
# C:\Users\himan\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
model.score(X_train,y_train) # checking for accuracy of the dataset which trained
# Out:
# 0.8597746318824688

# %%
model.score(X_test,y_test)
# Out:
# 0.8845501781743687

# %% [markdown]
# <b> himo</b>
